# %% [markdown]
# # Today's Youth Choice

# %% [markdown]
# Here , the data of different youths are given with their specification.
# The data is available as a CSV file.I am analyzing this data using Pandas Dataframe.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline 
from matplotlib import pyplot as plt

# %%
youth=pd.read_csv('survey.csv')

# %%
youth.head()
# Out:
#                         Timestamp                    Username  \
# 0  2022/01/26 3:24:04 PM GMT+5:30        19cse047@gweca.ac.in
# 1  2022/01/26 3:35:19 PM GMT+5:30   sanjaybasita480@gmail.com
# 2  2022/01/26 3:46:51 PM GMT+5:30  bhadouriyaeshika@gmail.com
# 3  2022/01/26 3:48:37 PM GMT+5:30      anushka81020@gmail.com
# 4  2022/01/26 3:50:02 PM GMT+5:30      jayanayak210@gmail.com
#
#     which app would you prefer  \
# 0                      Youtube
# 1  Educational apps(classroom)
# 2                      Youtube
# 3           books & references
# 4                      Youtube
#
#   Which app do you use the most?(favourite & frequently used app)  \
# 0                                          You Tube
# 1                                           You tube
# 2                                           You tube
# 3                                            Youtube
# 4                                            YouTube
#
# ...

# %% [markdown]
# QUESTION 1) find a null value in the dataset. if there is no null in a ny column then replace it with true.

# %%
youth.isnull().sum()
# Out:
# Timestamp                                                                     0
# Username                                                                      0
# which app would you prefer                                                    0
# Which app do you use the most?(favourite & frequently used app)               0
# most favourite social media app                                               0
# which feature is best in your favourite app                                   0
# which area will snatch your attention                                         0
# what extra reuirements you wish to have in your mobile apps.                  9
# How satisfied are you with the loading speed of your favourite mobile app?    0
# How would you rate the look and feel of your favourite  mobile app?           0
# which app was frustating ,which you ever installed.                           0
# what was annoying in that particular app                                      0
# dtype: int64

# %%
youth['what extra reuirements you wish to have in your mobile apps.']
# Out:
# 0                                            Long last
# 1                                                   NaN
# 2     Without writing and without speaking our app c...
# 3     Security and privacy that no one can hack my p...
# 4                                                   NaN
# 5                                                   NaN
# 6                                      Picture quality
# 7                                                   NaN
# 8                                       Virtual reality
# 9                                                   NaN
# 10                            Location of every person
# 11                                                  NaN
# 12                                              Nothing
# 13                                                  NaN
# 14    A time when phone can not be accessed because ...
# 15                            Run Speed should be high
# 16                                                  NaN
# ...

# %%
values={"what extra reuirements you wish to have in your mobile apps.":"prefer not to say"}

# %%
youth.fillna(value=values)
# Out:
#                           Timestamp                     Username  \
# 0    2022/01/26 3:24:04 PM GMT+5:30         19cse047@gweca.ac.in
# 1    2022/01/26 3:35:19 PM GMT+5:30    sanjaybasita480@gmail.com
# 2    2022/01/26 3:46:51 PM GMT+5:30   bhadouriyaeshika@gmail.com
# 3    2022/01/26 3:48:37 PM GMT+5:30       anushka81020@gmail.com
# 4    2022/01/26 3:50:02 PM GMT+5:30       jayanayak210@gmail.com
# 5    2022/01/26 3:56:32 PM GMT+5:30     Smilinggarima9@gmail.com
# 6    2022/01/26 4:03:30 PM GMT+5:30          ds6817457@gmail.com
# 7    2022/01/26 4:05:46 PM GMT+5:30      mahika.kakani@gmail.com
# 8    2022/01/26 4:24:08 PM GMT+5:30    kritikachordia1@gmail.com
# 9    2022/01/26 4:32:49 PM GMT+5:30    sudarshansen087@Gmail.com
# 10   2022/01/26 5:02:13 PM GMT+5:30      sushriyarampi@gmail.com
# 11   2022/01/26 6:11:32 PM GMT+5:30    avanisharma1009@gmail.com
# 12   2022/01/26 7:02:07 PM GMT+5:30         mmeena8261@gmail.com
# ...

# %% [markdown]
# Question 2) check what are the different types of favourite apps are there in the dataset and what is the count of each favourite app in the data

# %%
youth['most favourite social media app'].unique()
# Out:
# array(['instagram', 'whatsapp', 'Gmail'], dtype=object)

# %%
youth['most favourite social media app'].value_counts()
# Out:
# instagram    11
# whatsapp      8
# Gmail         2
# Name: most favourite social media app, dtype: int64

# %% [markdown]
# Question 3) Show the records where YouTube is the most preferred app of the youth and also print the count

# %%
youth['which app would you prefer'].isin(['Youtube'])
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4      True
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# Name: which app would you prefer, dtype: bool

# %%
youth['which app would you prefer'].isin(['Youtube']).value_counts()
# Out:
# False    14
# True      7
# Name: which app would you prefer, dtype: int64

# %%
youth
# Out:
#                           Timestamp                     Username  \
# 0    2022/01/26 3:24:04 PM GMT+5:30         19cse047@gweca.ac.in
# 1    2022/01/26 3:35:19 PM GMT+5:30    sanjaybasita480@gmail.com
# 2    2022/01/26 3:46:51 PM GMT+5:30   bhadouriyaeshika@gmail.com
# 3    2022/01/26 3:48:37 PM GMT+5:30       anushka81020@gmail.com
# 4    2022/01/26 3:50:02 PM GMT+5:30       jayanayak210@gmail.com
# 5    2022/01/26 3:56:32 PM GMT+5:30     Smilinggarima9@gmail.com
# 6    2022/01/26 4:03:30 PM GMT+5:30          ds6817457@gmail.com
# 7    2022/01/26 4:05:46 PM GMT+5:30      mahika.kakani@gmail.com
# 8    2022/01/26 4:24:08 PM GMT+5:30    kritikachordia1@gmail.com
# 9    2022/01/26 4:32:49 PM GMT+5:30    sudarshansen087@Gmail.com
# 10   2022/01/26 5:02:13 PM GMT+5:30      sushriyarampi@gmail.com
# 11   2022/01/26 6:11:32 PM GMT+5:30    avanisharma1009@gmail.com
# 12   2022/01/26 7:02:07 PM GMT+5:30         mmeena8261@gmail.com
# ...

# %% [markdown]
# Question 4) show relation between youth's satifaction for loading speed vs look & feel using matplotlib directory

# %%
x = youth['How satisfied are you with the loading speed of your favourite mobile app?'].tolist()

# %%
print(x)
# Out:
# [5, 2, 5, 5, 4, 5, 1, 4, 3, 3, 4, 5, 5, 4, 4, 3, 4, 4, 5, 4, 3]

# %%
y= youth['How would you rate the look and feel of your favourite  mobile app?'].tolist()

# %%
print(y)
# Out:
# [5, 4, 4, 5, 4, 5, 5, 4, 3, 3, 4, 4, 5, 4, 4, 5, 3, 5, 5, 5, 4]

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.scatter(x,y)
plt.title("speed satisfaction vs look & feel satisfaction")
plt.ylabel("loading speed")
plt.xlabel("look & feel")
plt.show()
